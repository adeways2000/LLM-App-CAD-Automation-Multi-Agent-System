# %%
import os

# %%
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
from dotenv import load_dotenv

# %%
import unittest

# %%
import unittest
import json
import sys
from typing import Dict, Any

# %%
# test_imports.py
import os
import sys
import json
from typing import TypedDict, Literal, Optional
